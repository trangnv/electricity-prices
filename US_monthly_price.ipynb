# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### US, states, monthly

# %%
file_path = "data/us/1122/us_electricity_price_Nov22/Average_retail_price_of_electricity_US_states.csv"

# %%
df = pd.read_csv(file_path)
df
# Out:
#                       description                  units  \
# 0       New England : all sectors  million kilowatthours
# 1       New England : residential  million kilowatthours
# 2        New England : commercial  million kilowatthours
# 3        New England : industrial  million kilowatthours
# 4    New England : transportation  million kilowatthours
# ..                            ...                    ...
# 361          Hawaii : residential  million kilowatthours
# 362           Hawaii : commercial  million kilowatthours
# 363           Hawaii : industrial  million kilowatthours
# 364       Hawaii : transportation  million kilowatthours
# 365                Hawaii : other  million kilowatthours
#
#                source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 0    ELEC.SALES.NEW-ALL.M   10623.0    9550.0   10067.0    8908.0    9323.0
# 1    ELEC.SALES.NEW-RES.M    4373.0    3525.0    3798.0    3165.0    2893.0
# ...

# %%
df.describe()
# Out:
#            Jan 2001      Feb 2001      Mar 2001      Apr 2001      May 2001  \
# count    305.000000    305.000000    305.000000    305.000000    305.000000
# mean    4076.298361   3571.600000   3531.832787   3336.265574   3468.727869
# std     7526.443730   6500.745198   6400.344901   6061.570701   6294.470963
# min        4.000000      3.000000      4.000000      3.000000      3.000000
# 25%      387.000000    350.000000    333.000000    310.000000    311.000000
# 50%     1418.000000   1298.000000   1256.000000   1244.000000   1260.000000
# 75%     4276.000000   3625.000000   3535.000000   3279.000000   3439.000000
# max    68544.000000  56924.000000  55792.000000  53828.000000  54963.000000
#
#           Jun 2001      Jul 2001      Aug 2001      Sep 2001      Oct 2001  \
# count    305.00000    305.000000    305.000000    305.000000    305.000000
# mean    3803.40000   4141.586885   4356.642623   3880.963934   3508.996721
# ...

# %% [markdown]
# ### US, states, monthly percentage change

# %%
df = pd.read_csv("data/us/1122/us_electricity_price_Nov22/Average_retail_price_of_electricity_US_states_pct_change.csv")
df.head()
# Out:
#                     description                  units            source key  \
# 0     New England : all sectors  million kilowatthours  ELEC.SALES.NEW-ALL.M
# 1     New England : residential  million kilowatthours  ELEC.SALES.NEW-RES.M
# 2      New England : commercial  million kilowatthours  ELEC.SALES.NEW-COM.M
# 3      New England : industrial  million kilowatthours  ELEC.SALES.NEW-IND.M
# 4  New England : transportation  million kilowatthours  ELEC.SALES.NEW-TRA.M
#
#    Jan 2001   Feb 2001  Mar 2001   Apr 2001   May 2001   Jun 2001   Jul 2001  \
# 0       NaN -10.100725  5.413613 -11.512864   4.658734   9.514105   0.773751
# 1       NaN -19.391722  7.744681 -16.666667  -8.593997  16.902869  10.703726
# 2       NaN -10.669162  9.350445 -10.227545   8.991462   7.221542  -1.278539
# 3       NaN  12.805209 -5.146705  -4.462475  18.630573   4.474273  -9.635974
# 4       NaN        NaN       NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
df.describe()
# Out:
#        Jan 2001    Feb 2001    Mar 2001    Apr 2001    May 2001    Jun 2001  \
# count       0.0  305.000000  305.000000  305.000000  305.000000  305.000000
# mean        NaN   -9.135472    0.415034   -5.630186    4.263322    7.610844
# std         NaN   10.821817   12.669227    9.454095    9.774172   10.234970
# min         NaN  -35.335581  -44.444444  -50.000000  -41.721854  -17.634746
# 25%         NaN  -14.741036   -4.896066  -11.512864   -0.055820    0.432463
# 50%         NaN   -9.871917    0.000000   -5.934455    4.090909    6.771429
# 75%         NaN   -5.797101    5.257143    0.000000    8.423475   12.229052
# max         NaN   50.000000  150.000000   69.491525   66.666667   42.096902
#
#          Jul 2001    Aug 2001    Sep 2001    Oct 2001  ...    Dec 2021  \
# count  305.000000  305.000000  305.000000  305.000000  ...  339.000000
# mean     7.568517    5.370796   -6.876615   -6.633970  ...    7.146418
# ...
