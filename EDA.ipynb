# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### US, states, monthly

# %%
df = pd.read_csv("data/us/Average_retail_price_of_electricity_US_states.csv")
df.head()
# Out:
#                     description                   units           source key  \
# 0     Connecticut : all sectors  cents per kilowatthour  ELEC.PRICE.CT-ALL.M
# 1     Connecticut : residential  cents per kilowatthour  ELEC.PRICE.CT-RES.M
# 2      Connecticut : commercial  cents per kilowatthour  ELEC.PRICE.CT-COM.M
# 3      Connecticut : industrial  cents per kilowatthour  ELEC.PRICE.CT-IND.M
# 4  Connecticut : transportation  cents per kilowatthour  ELEC.PRICE.CT-TRA.M
#
#    Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  Jun 2001  Jul 2001  ...  \
# 0      9.76      9.06      9.38      9.61      9.57      9.56      9.78  ...
# 1     10.70     10.23     10.60     10.87     11.20     11.06     11.00  ...
# 2      9.19      8.73      8.89      9.15      9.45      9.28      9.29  ...
# 3      8.09      7.25      7.53      7.79      7.50      7.48      7.94  ...
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN  ...
#
# ...

# %%
df.describe()
# Out:
#          Jan 2001    Feb 2001    Mar 2001    Apr 2001    May 2001    Jun 2001  \
# count  255.000000  255.000000  255.000000  255.000000  255.000000  255.000000
# mean     7.078980    7.216235    7.372824    7.483686    7.607843    7.870706
# std      3.040471    2.905729    3.063018    3.277404    3.110625    3.321589
# min      2.910000    2.880000    2.810000    2.880000    3.060000    3.320000
# 25%      5.120000    5.330000    5.425000    5.395000    5.525000    5.660000
# 50%      6.210000    6.560000    6.650000    6.630000    6.910000    7.210000
# 75%      8.085000    8.350000    8.490000    8.675000    8.930000    8.960000
# max     25.230000   24.210000   24.040000   26.350000   25.570000   28.360000
#
#          Jul 2001    Aug 2001    Sep 2001    Oct 2001  ...    Sep 2021  \
# count  255.000000  255.000000  255.000000  255.000000  ...  255.000000
# mean     7.977216    7.895804    7.695961    7.635412  ...   10.705255
# ...

# %% [markdown]
# ### US, states, monthly percentage change

# %%
df = pd.read_csv("data/us/Average_retail_price_of_electricity_US_states_pct_change.csv")
df.head()
# Out:
#                     description                   units           source key  \
# 0     Connecticut : all sectors  cents per kilowatthour  ELEC.PRICE.CT-ALL.M
# 1     Connecticut : residential  cents per kilowatthour  ELEC.PRICE.CT-RES.M
# 2      Connecticut : commercial  cents per kilowatthour  ELEC.PRICE.CT-COM.M
# 3      Connecticut : industrial  cents per kilowatthour  ELEC.PRICE.CT-IND.M
# 4  Connecticut : transportation  cents per kilowatthour  ELEC.PRICE.CT-TRA.M
#
#    Jan 2001   Feb 2001  Mar 2001  Apr 2001  May 2001  Jun 2001  Jul 2001  ...  \
# 0       NaN  -7.172131  3.532009  2.452026 -0.416233 -0.104493  2.301255  ...
# 1       NaN  -4.392523  3.616813  2.547170  3.035879 -1.250000 -0.542495  ...
# 2       NaN  -5.005441  1.832761  2.924634  3.278689 -1.798942  0.107759  ...
# 3       NaN -10.383189  3.862069  3.452855 -3.722721 -0.266667  6.149733  ...
# 4       NaN        NaN       NaN       NaN       NaN       NaN       NaN  ...
#
# ...

# %%
df.describe()
# Out:
#        Jan 2001    Feb 2001    Mar 2001    Apr 2001    May 2001    Jun 2001  \
# count       0.0  255.000000  255.000000  255.000000  255.000000  255.000000
# mean        NaN    2.980880    2.331546    1.446179    2.712272    3.536877
# std         NaN   12.938411   11.669274    7.769137    8.503055    7.805754
# min         NaN  -38.191882  -26.373626  -45.141066  -27.013752  -32.185749
# 25%         NaN   -0.430953   -1.528192   -0.964932   -0.636231   -0.143156
# 50%         NaN    2.214349    0.969697    1.562500    2.147651    2.672956
# 75%         NaN    5.175442    3.379216    4.475942    5.380293    5.628904
# max         NaN  174.117647  123.582090   31.949367   72.727273   48.454883
#
#          Jul 2001    Aug 2001    Sep 2001    Oct 2001  ...    Sep 2021  \
# count  255.000000  255.000000  255.000000  255.000000  ...  284.000000
# mean     1.366668   -0.112296   -2.478780    0.985910  ...    1.105134
# ...
