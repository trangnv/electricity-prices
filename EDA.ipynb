# %%
import pandas as pd

# %%
df = pd.read_csv("data/nrg_pc_204_c_linear.csv")
df
# Out:
#                       DATAFLOW        LAST UPDATE freq      nrg_cons nrg_prc  \
# 0      ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    A  KWH1000-2499    NETC
# 1      ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    A  KWH1000-2499    NETC
# 2      ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    A  KWH1000-2499    NETC
# 3      ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    A  KWH1000-2499    NETC
# 4      ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    A  KWH1000-2499    NETC
# ...                        ...                ...  ...           ...     ...
# 44739  ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    S    KWH_LT1000     VAT
# 44740  ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    S    KWH_LT1000     VAT
# 44741  ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    S    KWH_LT1000     VAT
# 44742  ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    S    KWH_LT1000     VAT
# 44743  ESTAT:NRG_PC_204_C(1.0)  27/06/22 23:00:00    S    KWH_LT1000     VAT
#
#       currency geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0          EUR  AL        2017     0.0000      NaN
# 1          EUR  AL        2018     0.0000      NaN
# 2          EUR  AL        2019     0.0000      NaN
# 3          EUR  AL        2020     0.0447        e
# 4          EUR  AL        2021     0.0000      NaN
# ...        ...  ..         ...        ...      ...
# 44739      EUR  IT     2016-S2     0.0287        d
# 44740      EUR  LI     2016-S2     0.0129      NaN
# 44741      NAC  IT     2016-S2     0.0287        d
# 44742      NAC  LI     2016-S2     0.0140      NaN
# 44743      PPS  IT     2016-S2     0.0292        d
#
# [44744 rows x 10 columns]

# %%
df.geo.unique()
# df.loc[(df.geo == 'AL') & (df.freq == 'A')]
# df.loc[(df.geo == 'AL') & (df.TIME_PERIOD == '2017')]
# Out:
# array(['AL', 'AT', 'BA', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EA', 'EE',
#        'EL', 'ES', 'EU27_2020', 'FI', 'FR', 'GE', 'HR', 'HU', 'IE', 'IS',
#        'IT', 'LI', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'MT', 'NL', 'NO',
#        'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK', 'TR', 'UA', 'UK', 'XK'],
#       dtype=object)

# %%
df.TIME_PERIOD.unique()
# Out:
# array(['2017', '2018', '2019', '2020', '2021', '2015-S2', '2016-S2',
#        '2008-S2', '2009-S2', '2010-S2', '2011-S2', '2012-S2', '2013-S2',
#        '2014-S2', '2007-S2'], dtype=object)
