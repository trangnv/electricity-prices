# %%
import pandas as pd

# %% [markdown]
# ### Electricity prices for household consumers - bi-annual data (from 2007 onwards)
# Europe

# %%
# df = pd.read_csv("data/nrg_pc_204_c_linear.csv")
df = pd.read_csv("data/nrg_pc_204_linear-electricity_prices_household.csv")
df
# Out:
#                     DATAFLOW        LAST UPDATE freq  product   consom unit  \
# 0      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 1      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 2      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 3      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 4      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# ...                      ...                ...  ...      ...      ...  ...
# 48175  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 48176  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 48177  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 48178  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 48179  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
#
# ...

# %% [markdown]
# - AL: Albania
# - All taxes and levies included
# - currency: EUR

# %%
df.geo.unique()
# df.loc[(df.geo == 'AL') & (df.freq == 'A')]
# df.loc[(df.geo == 'AL') & (df.TIME_PERIOD == '2011-S1') & (df.currency == 'EUR')]
df.loc[(df.geo == 'AL') & (df.tax == 'I_TAX') & (df.currency == 'EUR')]
# Out:
#                     DATAFLOW        LAST UPDATE freq  product   consom unit  \
# 0      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 1      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 2      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 3      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# 4      ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161901  KWH
# ...                      ...                ...  ...      ...      ...  ...
# 38562  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 38563  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 38564  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 38565  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
# 38566  ESTAT:NRG_PC_204(1.0)  27/06/22 23:00:00    S     6000  4161905  KWH
#
# ...

# %%
df.TIME_PERIOD.unique()
# Out:
# array(['2017', '2018', '2019', '2020', '2021', '2015-S2', '2016-S2',
#        '2008-S2', '2009-S2', '2010-S2', '2011-S2', '2012-S2', '2013-S2',
#        '2014-S2', '2007-S2'], dtype=object)

# %% [markdown]
# ### US, states, monthly

# %%
df = pd.read_csv("data/us/Average_retail_price_of_electricity_states.csv")
df
# Out:
#                              description                   units  \
# 0    Average retail price of electricity  cents per kilowatthour
# 1                          United States                     NaN
# 2                            New England                     NaN
# 3                            Connecticut  cents per kilowatthour
# 4              Connecticut : all sectors  cents per kilowatthour
# ..                                   ...                     ...
# 364                 Hawaii : residential  cents per kilowatthour
# 365                  Hawaii : commercial  cents per kilowatthour
# 366                  Hawaii : industrial  cents per kilowatthour
# 367              Hawaii : transportation  cents per kilowatthour
# 368                       Hawaii : other  cents per kilowatthour
#
#                source key Jan 2001 Feb 2001 Mar 2001 Apr 2001 May 2001  \
# 0                     NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
df.loc[(df.description == 'Connecticut : residential') ]#& (df.tax == 'I_TAX') & (df.currency == 'EUR')]
# Out:
#                  description                   units           source key  \
# 5  Connecticut : residential  cents per kilowatthour  ELEC.PRICE.CT-RES.M
#
#   Jan 2001 Feb 2001 Mar 2001 Apr 2001 May 2001 Jun 2001 Jul 2001  ...  \
# 5    10.70    10.23    10.60    10.87    11.20    11.06    11.00  ...
#
#   Sep 2021 Oct 2021 Nov 2021 Dec 2021 Jan 2022 Feb 2022 Mar 2022 Apr 2022  \
# 5    22.42    22.85    21.35    20.85    22.28    26.48    25.61    27.10
#
#   May 2022 Jun 2022
# 5    24.81    25.43
#
# [1 rows x 261 columns]
